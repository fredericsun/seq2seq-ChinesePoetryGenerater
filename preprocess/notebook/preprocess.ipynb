# %%
import os
import h5py

import json_utils
import process_raw


JSON_DATA_PATH='../../../data/json/'
HDF5_DATA_PATH='../../../data/hdf5/'


# @return poems: a list of all poem dictionarys
def get_data():

	# get all hdf5 data to a list of dictionarys

	file_names=os.listdir(HDF5_DATA_PATH)

	poems=[]

	for f in file_names:

		hdf5_path=HDF5_DATA_PATH+f
		p=process_raw.read_poems_from_hdf5(hdf5_path)

		poems += p

	return poems

# %%
poems=get_data()

# %%
poems
# Out:
# [{'author': array('白居易', dtype=object),
#   'paragraphs': ['好去民曹李判官', '少貪公事且謀歡', '男兒未死爭能料', '莫作忠州刺史看'],
#   'title': array('戲贈戶部李巡官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巫女廟花紅似粉', '昭君村柳翠於眉', '誠知老去風情少', '見此爭無一句詩'],
#   'title': array('題峽中石上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['蕃草席鋪楓葉岸', '竹枝歌送菊花杯', '明年尚作南賓守', '或可重陽更一來'],
#   'title': array('九日題塗溪', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['親故尋回駕', '妻孥未出關', '鳳皇池上月', '送我過商山'],
#   'title': array('宿陽城驛對月', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['往恨今愁應不殊', '題詩梁下又踟躕', '羨君猶夢見兄弟', '我到天明睡亦無'],
#   'title': array('赴杭州重宿棣華驛見楊八舊詩感題一絕', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['劫風火起燒荒宅', '苦海波生蕩破船', '力小無因救焚溺', '清涼山下且安禪'],
#   'title': array('寓言題僧', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['日下風高野路涼', '緩驅疲馬闇思鄉', '渭村秋物應如此', '棗赤梨紅稻穗黃'],
#   'title': array('內鄉村路作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['坐酌泠泠水', '看煎瑟瑟塵', '無由持一盌', '寄與愛茶人'],
#   'title': array('山泉煎茶有懷', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲雨三年別', '風波萬里行', '愁來正蕭索', '況見古人名'],
#   'title': array('吉祥寺見錢侍郎題名', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['虛白堂前衙退後', '更無一事到中心', '移牀就日簷間臥', '臥詠閑詩側枕琴'],
#   'title': array('虛白堂', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫粉筆含尖火燄', '紅胭脂染小蓮花', '芳情鄉思知多少', '惱得山僧悔出家'],
#   'title': array('題靈隱寺紅辛夷花戲酬光上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['謝安山下空攜妓', '柳惲洲邊只賦詩', '爭及湖亭今日會', '嘲花詠水贈蛾眉'],
#   'title': array('候仙亭同諸客醉作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['城上鼕鼕鼓', '朝衙復晚衙', '爲君慵不出', '落盡遶城花'],
#   'title': array('城上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['競渡相傳爲汨羅', '不能止遏意無他', '自經放逐來顦顇', '能校靈均死幾多'],
#   'title': array('和萬州楊使君四絕句 競渡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['大見騰騰詩酒客', '不憂生計似君稀', '到舍將何作寒食', '滿船唯載樹陰歸'],
#   'title': array('送李校書趂寒食歸義興山居', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['闇誦黃庭經在口', '閑攜青竹杖隨身', '晚花新筍堪爲伴', '獨入林行不要人'],
#   'title': array('獨行', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫房日照胭脂拆', '素豔風吹膩粉開', '怪得獨饒脂粉態', '木蘭曾作女郎來'],
#   'title': array('戲題木蘭花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['重重照影看容鬢', '不見朱顏見白絲', '失却少年無處覓', '泥他湖水欲何爲'],
#   'title': array('湖中自照', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南館西軒兩樹櫻', '春條長足夏陰成', '素華朱實今雖盡', '碧葉風來別有情'],
#   'title': array('樟亭雙櫻樹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['郭外迎人月', '湖邊醒酒風', '誰留使君飲', '紅燭在舟中'],
#   'title': array('湖上夜飲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晚涼思飲兩三杯', '召得江頭酒客來', '莫怕秋無伴醉物', '水蓮花盡木蓮開'],
#   'title': array('木芙蓉花下招客飲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['秋愛冷吟春愛醉', '詩家眷屬酒家仙', '若教早被浮名繫', '可得閑遊三十年'],
#   'title': array('重酬周判官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['亂蓬爲鬢布爲巾', '曉蹋寒山自負薪', '一種錢唐江畔女', '著紅騎馬是何人'],
#   'title': array('代賣薪女贈諸妓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲水埋藏恩德洞', '簪裾束縛使君身', '暫來不宿歸州去', '應被山呼作俗人'],
#   'title': array('予以長慶二年冬十月到杭州明年秋九月始與范陽盧賈汝南周元範蘭陵蕭悅清河崔求東萊劉方輿同遊恩德寺之泉洞竹石籍甚久矣及茲目擊果愜心期因自嗟云到郡周歲方來入寺半日復去俯視朱綬仰睇白雲有媿於心遂留絕句',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['聞君澤畔傷春草', '憶在天門街裏時', '漠漠淒淒愁滿眼', '就中惆悵是江蘺'],
#   'title': array('和萬州楊使君四絕句 江邊草', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遙羨青雲裏', '祥鸞正引雛', '自憐滄海伴', '老蚌不生珠'],
#   'title': array('見李蘇州示男阿武詩自感成詠', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['頭陀獨宿寺西峰', '百尺禪菴半夜鐘', '煙月蒼蒼風瑟瑟', '更無雜樹對山松'],
#   'title': array('題清頭陀', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['形羸自覺朝飡減', '睡少偏知夜漏長', '實事漸消虛事在', '銀魚金帶遶腰光'],
#   'title': array('自歎二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['二毛曉落梳頭嬾', '兩眼春昏點藥頻', '唯有閑行猶得在', '心情未到不如人'],
#   'title': array('自歎二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小書樓下千竿竹', '深火爐前一醆燈', '此處與誰相伴宿', '燒丹道士坐禪僧'],
#   'title': array('竹樓宿', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['莫言魯國書生懦', '莫把杭州刺史欺', '醉客請君開眼望', '綠楊風下有紅旗'],
#   'title': array('戲醉客', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['何年植向仙壇上', '早晚移栽到梵家', '雖在人間人不識', '與君名作紫陽花'],
#   'title': array('紫陽花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['黃壤詎知我', '白頭徒憶君', '唯將老年淚', '一灑故人文'],
#   'title': array('題故元少尹集後二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遺文三十軸', '軸軸金玉聲', '龍門原上土', '埋骨不埋名'],
#   'title': array('題故元少尹集後二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['古人唱歌兼唱情', '今人唱歌唯唱聲', '欲說向君君不會', '試將此語問楊瓊'],
#   'title': array('問楊瓊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['東都綠李萬州栽', '君手封題我手開', '把得欲嘗先悵望', '與渠同別故鄉來'],
#   'title': array('和萬州楊使君四絕句 嘉慶李', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['羅敷歛雙袂', '樊姬獻一杯', '不見舒員外', '秋菊爲誰開'],
#   'title': array('九日代羅樊二妓招舒著作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['淡紅花帔淺檀蛾', '睡臉初開似剪波', '坐對珠籠閑理曲', '琵琶鸚鵡語相和'],
#   'title': array('吳宮辭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['燭下尊前一分手', '舟中岸上兩迴頭', '歸來虛白堂中夢', '合眼先應到越州'],
#   'title': array('荅微之上船後留別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['煙波盡處一點白', '應是西陵古驛臺', '知在臺邊望不見', '暮潮空送渡船迴'],
#   'title': array('荅微之泊西陵驛見寄', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['宴遊寢食漸無味', '桮酒管弦徒繞身', '賓客歡娛僮僕飽', '始知官職爲它人'],
#   'title': array('自感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三月盡是頭白日', '與春老別更依依', '憑鶯爲向楊花道', '絆惹春風莫放歸'],
#   'title': array('柳絮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['席上爭飛使君酒', '歌中多唱舍人詩', '不知明日休官後', '逐我東山去是誰'],
#   'title': array('醉戲諸妓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早潮纔落晚潮來', '一月周流六十回', '不獨光陰朝復暮', '杭州老去被潮催'],
#   'title': array('潮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['已留舊政布中和', '又付新詞與豔歌', '但是人家有遺愛', '就中蘇小感恩多'],
#   'title': array('聞歌妓唱嚴郎中詩因以絕句寄之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['正抽碧線繡紅羅', '忽聽黃鶯歛翠蛾', '秋思冬愁春悵望', '大都不稱意時多'],
#   'title': array('急樂世辭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['秋蕣晚英無豔色', '何因栽種在人家', '使君自別羅敷面', '爭解回頭愛白花'],
#   'title': array('和萬州楊使君四絕句 白槿花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['憑仗江波寄一辭', '不須惆悵報微之', '猶勝往歲峽中別', '灩澦堆邊招手時'],
#   'title': array('重寄別微之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['主人頭白官仍冷', '去後憐君是底人', '試謁會稽元相去', '不妨相見却殷勤'],
#   'title': array('別周軍事', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['莫惜新衣舞柘枝', '也從塵汚汗霑垂', '料君即却歸朝去', '不見銀泥衫故時'],
#   'title': array('看常州柘枝贈賈使君', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['憶君我正泊行舟', '望我君應上郡樓', '萬里月明同此夜', '黃河東面海西頭'],
#   'title': array('河陰夜泊憶微之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自別錢塘山水後', '不多飲酒嬾吟詩', '欲將此意憑迴櫂', '報與西湖風月知'],
#   'title': array('杭州迴舫', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['辭章諷詠成千首', '心行歸依向一乘', '坐倚繩牀閑自念', '前生應是一詩僧'],
#   'title': array('愛詠詩', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['閑官臥疾絕經過', '居處蕭條近洛河', '水北水南秋月夜', '管弦聲少杵聲多'],
#   'title': array('臥疾', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['東宮白庶子', '南寺遠禪師', '何處遙相見', '心無一事時'],
#   'title': array('遠師', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['葷羶停夜食', '吟詠散秋懷', '笑問東林老', '詩應不破齋'],
#   'title': array('問遠師', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['君以曠懷宜靜境', '我因蹇步稱閑官', '閉門足病非高士', '勞作雲心鶴眼看'],
#   'title': array('酬楊八', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['反照前山雲樹明', '從君苦道似華清', '試聽腸斷巴猨呌', '早晚驪山有此聲'],
#   'title': array('和行簡望郡南山', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朱欄映晚樹', '金魄落秋池', '還似錢唐夜', '西樓月出時'],
#   'title': array('池西亭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['天氣妍和水色鮮', '閑吟獨步小橋邊', '池塘草綠無佳句', '虛臥春窗夢阿憐'],
#   'title': array('夢行簡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['非琴非瑟亦非箏', '撥柱推弦調未成', '欲散白頭千萬恨', '只消紅袖兩三聲'],
#   'title': array('雲和', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['欲隨年少強遊春', '自覺風光不屬身', '歌舞屏風花障上', '幾時曾畫白頭人'],
#   'title': array('春老', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晚來籃轝雪中回', '喜遇君家門正開', '唯要主人青眼待', '琴詩談笑自將來'],
#   'title': array('春雪過皇甫家', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洞房門上挂桑弧', '香水盆中浴鳳雛', '還似初生三日魄', '嫦娥滿月即成珠'],
#   'title': array('崔侍御以孩子三日示其所生詩見示因以二絕句和之 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['愛惜肯將同寶玉', '喜歡應勝得王侯', '弄璋詩句多才思', '愁殺無兒老鄧攸'],
#   'title': array('崔侍御以孩子三日示其所生詩見示因以二絕句和之 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洛陽陌上少交親', '履道城邊欲暮春', '崔在吳興元在越', '出門騎馬覓何人'],
#   'title': array('晚春寄微之幷崔湖州', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['上馬行數里', '逢花傾一桮', '更無停泊處', '還是覓君來'],
#   'title': array('訪皇甫七', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['君顏貴茂不清羸', '君句雄華不苦悲', '何事遣君還似我', '髭鬚早白亦無兒'],
#   'title': array('吟前篇因寄微之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅顆珍珠誠可愛', '白鬚太守亦何癡', '十年結子知誰在', '自向庭中種荔枝'],
#   'title': array('種荔枝', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['子墮本從天竺寺', '根盤今在闔閭城', '當時應逐南風落', '落向人間取次生'],
#   'title': array('東城桂三首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['霜雪壓多雖不死', '荆榛長疾欲相埋', '長憂落在樵人手', '賣作蘇州一束柴'],
#   'title': array('東城桂三首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遙知天上桂花孤', '試問嫦娥更要無'],
#   'title': array('東城桂三首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['池邊新種七株梅', '欲到花時點檢來', '莫怕長洲桃李妬', '今年好爲使君開'],
#   'title': array('新栽梅', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['聞道毗陵詩酒興', '近來積漸學姑蘇', '罨頭新令從偷去', '刮骨清吟得似無'],
#   'title': array('戲和賈常州醉中二絕句 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['越調管吹留客曲', '吳吟詩送暖寒杯', '娃宮無限風流事', '好遣孫心暫學來'],
#   'title': array('戲和賈常州醉中二絕句 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['好風朧月清明夜', '碧砌紅軒刺史家', '獨繞迴廊行復歇', '遙聽弦管暗看花'],
#   'title': array('清明夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['一春惆悵殘三日', '醉問周郎憶得無', '柳絮送人鶯勸酒', '去年今日別東都'],
#   'title': array('三月二十八日贈周判官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['腰痛拜迎人客倦', '眼昏勾押簿書難', '辭官歸去緣衰病', '莫作陶潛范蠡看'],
#   'title': array('酬別周從事二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洛下田園久拋擲', '吳中歌酒莫留連', '嵩陽雲樹伊川月', '已校歸遲四五年'],
#   'title': array('酬別周從事二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['天涯深峽無人地', '歲暮窮陰欲夜天', '不向東樓時一醉', '如何擬過二三年'],
#   'title': array('東樓醉', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['已知臘子能裁服', '復報龜兒解詠燈', '巧婦才人常薄命', '莫教男女苦多能'],
#   'title': array('見小姪龜兒詠燈詩幷臘娘製衣因寄行簡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['寫了吟看滿卷愁', '淺紅牋紙小銀鉤', '未容寄與微之去', '已被人傳到越州'],
#   'title': array('寫新詩寄微之偶題卷後', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['塵纓忽解誠堪喜', '世網重來未可知', '莫忘全吳館中夢', '嶺南泥雨步行時'],
#   'title': array('寶曆二年八月三十日夜夢後作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['半月悠悠在廣陵', '何樓何塔不同登', '共憐筋力猶堪在', '上到棲靈第九層'],
#   'title': array('與夢得同登棲靈塔', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['揚州驛裏夢蘇州', '夢到花橋水閣頭', '覺後不知馮侍御', '此中昨夜共誰遊'],
#   'title': array('夢蘇州水閣寄馮侍御', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['姓白使君無麗句', '名休座主有新文', '禪心不合生分別', '莫愛餘霞嫌碧雲'],
#   'title': array('荅次休上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曾家機上聞投杼', '尹氏園中見掇蜂', '但以恩情生隙罅', '何人不解作江充'],
#   'title': array('思子臺有感二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['闇生魑魅蠹生蟲', '何異讒生疑阻中', '但使武皇心似燭', '江充不敢作江充'],
#   'title': array('思子臺有感二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['山陽太守政嚴明', '吏靜人安無犬驚', '不知靈藥根成狗', '怪得時聞吠夜聲'],
#   'title': array('和郭使君題枸杞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['槐花雨潤新秋地', '桐葉風翻欲夜天', '盡日後廳無一事', '白頭老監枕書眠'],
#   'title': array('祕省後廳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['莫辭數數醉東樓', '除醉無因破得愁', '唯有綠樽紅燭下', '暫時不似在忠州'],
#   'title': array('東樓招客夜飲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['野徑行無伴', '僧房宿有期', '塗山來去熟', '唯是馬蹄知'],
#   'title': array('塗山寺獨遊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['百千家似圍棊局', '十二街如種菜畦', '遙認微微入朝火', '一條星宿五門西'],
#   'title': array('登觀音臺望城', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['臨高始見人寰小', '對遠方知色界空', '回首却歸朝市去', '一稊米落太倉中'],
#   'title': array('登靈應臺北望', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['兀兀出門何處去', '新昌街晚樹陰斜', '馬蹄知意緣行熟', '不向楊家即庾家'],
#   'title': array('閑出', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早風吹土滿長衢', '驛騎星軺盡疾驅', '共笑籃舁亦稱使', '日馳一驛向東都'],
#   'title': array('奉使途中戲贈張常侍', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['吳中白藕洛中栽', '莫戀江南花嬾開', '萬里攜歸爾知否', '紅蕉朱槿不將來'],
#   'title': array('種白蓮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不獨君嗟我亦嗟', '西風北雪殺南花', '不知月夜魂歸處', '鸚鵡洲頭第幾家'],
#   'title': array('和劉郎中傷鄂姬', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['兔園春雪梁王會', '想對金罍詠玉塵', '今日相如身在此', '不知客右坐何人'],
#   'title': array('雪中寄令狐相公兼呈夢得', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['辭鄉遠隔華亭水', '逐我來棲緱嶺雲', '慚媿稻粱長不飽', '未曾回眼向雞羣'],
#   'title': array('有雙鶴留在洛中忽見劉郎中依然鳴顧劉因爲鶴嘆二篇寄予予以二絕句答之 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['荒草院中池水畔', '銜恩不去又經春', '見君驚喜雙回顧', '應爲吟聲似主人'],
#   'title': array('有雙鶴留在洛中忽見劉郎中依然鳴顧劉因爲鶴嘆二篇寄予予以二絕句答之 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自知清冷似冬凌', '每被人呼作律僧', '今夜酒醺羅綺暖', '被君融盡玉壺冰'],
#   'title': array('醉後戲題', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['使君何在在江東', '池柳初黃杏欲紅', '有興即來閑便宿', '不知誰是主人翁'],
#   'title': array('宿竇使君莊水亭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['龍門澗下濯塵纓', '擬作閑人過此生', '筋力不將諸處用', '登山臨水詠詩行'],
#   'title': array('龍門下作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晚起春寒慵裹頭', '客來池上偶同遊', '東臺御史多提舉', '莫按金章繫布裘'],
#   'title': array('姚侍御見過戲贈', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['揚子津頭月下', '臨都驛裏燈前', '昨日老於前日', '去年春似今年'],
#   'title': array('臨都驛答夢得六言二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['謝守歸爲秘監', '馮公老作郎官', '前事不須問著', '新詩且更吟看'],
#   'title': array('臨都驛答夢得六言二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['高情雅韻三峯守', '主領清光管白雲', '自笑亦曾爲刺史', '蘇州肥膩不如君'],
#   'title': array('和錢華州題少華清光絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金馬門前回劒珮', '鐵牛城下擁旌旗', '他時萬一爲交代', '留取甘棠三兩枝'],
#   'title': array('送陝府王大夫', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['幸與松筠相近栽', '不隨桃李一時開', '杏園豈敢妨君去', '未有花時且看來'],
#   'title': array('代迎春花招劉郎中', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金英翠萼帶春寒', '黃色花中有幾般', '憑君與向遊人道', '莫作蔓菁花眼看'],
#   'title': array('翫迎春花贈楊郎中', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['把酒承花花落頻', '花香酒味相和春', '莫言不是江南會', '虛白亭中舊主人'],
#   'title': array('座上贈盧判官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['八十秦翁老不歸', '南賓太守乞寒衣', '再三憐汝非他意', '天寶遺民見漸稀'],
#   'title': array('贈康叟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['瞿唐峽口水煙低', '白帝城頭月向西', '唱到竹枝聲咽處', '寒猨闇鳥一時啼'],
#   'title': array('竹枝詞四首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曲江西岸又春風', '萬樹花前一老翁', '遇酒逢花還且醉', '若論惆悵事何窮'],
#   'title': array('曲江有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['怪君把酒偏惆悵', '曾是貞元花下人', '自別花來多少事', '東風二十四回春'],
#   'title': array('杏園花下贈劉郎中', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['老去將何散老愁', '新教小玉唱伊州', '亦應不得多年聽', '未教成時已白頭'],
#   'title': array('伊州', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['嬴女偷乘鳳去時', '洞中潛歇弄瓊枝', '不緣啼鳥春饒舌', '青瑣仙郎可得知'],
#   'title': array('酬嚴給事', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['西來爲看秦山雪', '東去緣尋洛苑春', '來去騰騰兩京路', '閑行除我更無人'],
#   'title': array('京路', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['每逢人靜慵多歇', '不計程行困即眠', '上得籃轝未能去', '春風敷水店門前'],
#   'title': array('華州西', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['銀花鑿落從君勸', '金屑琵琶爲我彈', '不獨送春兼送老', '更嘗一着更聽看'],
#   'title': array('送春', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['久別偶相逢', '俱疑是夢中', '即今歡樂事', '放醆又成空'],
#   'title': array('逢舊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['低花樹暎小妝樓', '春入眉心兩點愁', '斜倚欄干背鸚鵡', '思量何事不回頭'],
#   'title': array('春詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['翠黛眉低歛', '紅珠淚暗銷', '從來恨人意', '不省似今朝'],
#   'title': array('恨詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['竹枝苦怨怨何人', '夜靜山空歇又聞', '蠻兒巴女齊聲唱', '愁殺江樓病使君'],
#   'title': array('竹枝詞四首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['池晚蓮芳謝', '窗秋竹意深', '更無人作伴', '唯對一張琴'],
#   'title': array('池窗', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['香醅淺酌浮如蟻', '雪鬢新梳薄似蟬', '爲報洛城花酒道', '莫辭送老二三年'],
#   'title': array('花酒', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小亭門向月斜開', '滿地涼風滿地苔', '此院好彈秋思處', '終須一夜抱琴來'],
#   'title': array('楊家南亭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['尚書清白臨南海', '雖飲貪泉心不回', '唯向詩中得珠玉', '時時寄到帝鄉來'],
#   'title': array('廣府胡尚書頻寄詩因答絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['高臥深居不見人', '功名斗藪似灰塵', '唯留一部清商樂', '月下風前伴老身'],
#   'title': array('讀鄂公傳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['蟲聲冬思苦於秋', '不解愁人聞亦愁', '我是老翁聽不畏', '少年莫聽白君頭'],
#   'title': array('冬夜聞蟲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['戛玉敲冰聲未停', '嫌雲不遏入青冥', '爭得黃金滿衫袖', '一時拋與斷年聽'],
#   'title': array('聽田順兒歌', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['撥撥弦弦意不同', '胡啼番語兩玲瓏', '誰能截得曹剛手', '插向重蓮衣袖中'],
#   'title': array('聽曹剛琵琶兼示重蓮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巧拙賢愚相是非', '何如一醉盡忘機', '君知天地中寬窄', '鵰鶚鸞皇各自飛'],
#   'title': array('對酒五首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['蝸牛角上爭何事', '石火光中寄此身', '隨富隨貧且歡樂', '不開口笑是癡人'],
#   'title': array('對酒五首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巴東船舫上巴西', '波面風生雨脚齊', '水蓼冷花紅簇簇', '江蘺濕葉碧淒淒'],
#   'title': array('竹枝詞四首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['丹砂見火去無迹', '白髮泥人來不休', '賴有酒仙相暖熱', '松喬醉即到前頭'],
#   'title': array('對酒五首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['百歲無多時壯健', '一春能幾日晴明', '相逢且莫推辭醉', '聽唱陽關第四聲'],
#   'title': array('對酒五首 四', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['昨日低眉問疾來', '今朝收淚弔人回', '眼前流例君看取', '且遣琵琶送一桮'],
#   'title': array('對酒五首 五', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['欲悟色空爲佛事', '故栽芳樹在僧家', '細看便是華嚴偈', '方便風開智慧花'],
#   'title': array('僧院花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['簷前新葉覆殘花', '席上餘桮對早茶', '好是老身銷日處', '誰能騎馬傍人家'],
#   'title': array('不出', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晝聽笙歌夜醉眠', '若非月下即花前', '如今老病須知分', '不負春來二十年'],
#   'title': array('老病', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遊山弄水攜詩卷', '看月尋花把酒桮', '六事盡思君作伴', '幾時歸到洛陽來'],
#   'title': array('憶晦叔', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['耳根得聽琴初暢', '心地忘機酒半酣', '若使啓期兼解醉', '應言四樂不言三'],
#   'title': array('琴酒', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['琴中古曲是幽蘭', '爲我慇懃更弄看', '欲得身心俱靜好', '自彈不及聽人彈'],
#   'title': array('聽幽蘭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['銘旌官重威儀盛', '騎吹聲繁鹵簿長', '後魏帝孫唐宰相', '六年七月葬咸陽'],
#   'title': array('元相公挽歌詞三首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['江畔誰人唱竹枝', '前聲斷咽後聲遲', '怪來調苦緣詞苦', '多是通州司馬詩'],
#   'title': array('竹枝詞四首 四', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['墓門已閉笳簫去', '唯有夫人哭不休', '蒼蒼露草咸陽壠', '此是千秋第一秋'],
#   'title': array('元相公挽歌詞三首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['送葬萬人皆慘澹', '反虞駟馬亦悲鳴', '琴書劒珮誰收拾', '三歲遺孤新學行'],
#   'title': array('元相公挽歌詞三首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['歡愛今何在', '悲啼亦是空', '同爲一夜夢', '共過十年中'],
#   'title': array('結之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['病上籃輿相送來', '衰容秋思兩悠哉', '涼風褭褭吹槐子', '却請行人勸一桮'],
#   'title': array('送客', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['清緊如敲玉', '深圓似轉簧', '一聲腸一斷', '能有幾多腸'],
#   'title': array('題周家歌者', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['寒宵勸酒君須飲', '君是孤眠七十身', '莫道非人身不煖', '十分一醆煖於人'],
#   'title': array('戲答皇甫監', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['氈帳胡琴出塞曲', '蘭塘越櫂弄潮聲', '何言此處同風月', '薊北江南萬里情'],
#   'title': array('池邊即事', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['臥在漳濱滿十旬', '起爲商皓伴三人', '從今且莫嫌身病', '不病何由索得身'],
#   'title': array('病免後喜除賓客', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['笙歌惆悵欲爲別', '風景闌珊初過春', '爭得遣君詩不苦', '黃河岸上白頭人'],
#   'title': array('別陝州王司馬', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['半日停車馬', '何人在白家', '慇懃蕭庶子', '愛酒不嫌茶'],
#   'title': array('蕭庶子相過', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['江上新樓名四望', '東西南北水茫茫', '無由得與君攜手', '同凭欄干一望鄉'],
#   'title': array('寄題楊萬州四望樓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['乍到頻勞問所須', '所須非玉亦非珠', '愛君水閣宜閑詠', '每有詩成許去無'],
#   'title': array('荅尉遲少尹問所須', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['牆西明月水東亭', '一曲霓裳按小伶', '不敢邀君無別意', '弦生管澀未堪聽'],
#   'title': array('荅蘇庶子月夜聞家僮奏樂見贈', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['白藕新花照水開', '紅窗小舫信風迴', '誰教一片江南興', '逐我慇懃萬里來'],
#   'title': array('白蓮池汎舟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['習靜心方泰', '勞生事漸稀', '可憐安穩地', '捨此欲何歸'],
#   'title': array('酬裴相公見寄二絕 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['一雙垂翅鶴', '數首解嘲文', '總是迂閑物', '爭堪伴相君'],
#   'title': array('酬裴相公見寄二絕 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['勞將白叟比黃公', '今古由來事不同', '我有商山君未見', '清泉白石在胸中'],
#   'title': array('荅崔十八', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['但喜暑隨三伏去', '不知秋送二毛來', '更無別計相寬慰', '故遣陽關勸一桮'],
#   'title': array('荅蘇六', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['下馬閑行伊水頭', '涼風清景勝春遊', '何事古今詩句裏', '不多說著洛陽秋'],
#   'title': array('秋遊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['右翅低垂左脛傷', '可憐風貌甚昂藏', '亦知白日青天好', '未要高飛且養瘡'],
#   'title': array('歎鶴病', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['風飄雨灑簾帷故', '竹暎松遮燈火深', '宿客不來嫌冷落', '一尊酒對一張琴'],
#   'title': array('期宿客不至', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['忠萬樓中南北望', '南州煙水北州雲', '兩州何事偏相憶', '各是籠禽作使君'],
#   'title': array('荅楊使君登樓見憶', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['問君移竹意如何', '慎勿排行但間窠', '多種少栽皆有意', '大都少校不如多'],
#   'title': array('問移竹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['滿園花菊鬱金黃', '中有孤叢色似霜', '還似今朝歌酒席', '白頭翁入少年場'],
#   'title': array('重陽席上賦白菊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['貧無好物堪爲信', '雙榼雖輕意不輕', '願奉謝公池上酌', '丹心綠酒一時傾'],
#   'title': array('寄兩銀榼與裴侍郎因題兩絕句 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['慣和麴糵堪盛否', '重用鹽梅試洗看', '小器不知容幾許', '襄陽米賤酒升寬'],
#   'title': array('寄兩銀榼與裴侍郎因題兩絕句 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['細水涓涓似淚流', '日西惆悵小橋頭', '衰楊葉盡空枝在', '猶被霜風吹不休'],
#   'title': array('小橋柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['八月涼風吹白幕', '寢門廊下哭微之', '妻孥朋友來相弔', '唯道皇天無所知'],
#   'title': array('哭微之二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['文章卓犖生無敵', '風骨英靈歿有神', '哭送咸陽北原上', '可能隨例作灰塵'],
#   'title': array('哭微之二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['劉郎劉郎莫先起', '蘇臺蘇臺隔雲水', '酒醆來從一百分', '馬頭去便三千里'],
#   'title': array('醉中重留夢得', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不愁陌上春光盡', '亦任庭前日影斜', '面黑眼昏頭雪白', '老應無可更增加'],
#   'title': array('任老', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['火急歡娛慎勿遲', '眼看老病悔難追', '尊前花下歌筵裏', '會有求來不得時'],
#   'title': array('勸歡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['身入青雲無見日', '手栽紅樹又逢春', '唯留花向樓前著', '故故拋愁與後人'],
#   'title': array('題東樓前李使君所種櫻桃花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晚從履道來歸府', '街路雖長尹不嫌', '馬上涼於牀上坐', '綠槐風透紫蕉衫'],
#   'title': array('晚歸府', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['夜上九潭誰是伴', '雲隨飛蓋月隨桮', '明年尚作三川守', '此地兼將歌舞來'],
#   'title': array('宿龍潭寺', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['白石清泉拋濟口', '碧幢紅斾照河陽', '邨人都不知時事', '猶自呼爲處士莊'],
#   'title': array('過溫尚書舊莊', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['心如定水隨形應', '口似懸河逐病治', '曾向衆中先禮拜', '西方去日莫相遺'],
#   'title': array('贈僧五首 神照上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自出家來長自在', '緣身一衲一繩牀', '令人見即心無事', '每一相逢是道場'],
#   'title': array('贈僧五首 自遠禪師', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['榮華恩愛棄成唾', '戒定真如和作香', '今古雖殊同一法', '瞿曇拋却轉輪王'],
#   'title': array('贈僧五首 宗實上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['梓潼眷屬何年別', '長壽壇場近日開', '應是蜀人皆度了', '法輪移向洛中來'],
#   'title': array('贈僧五首 清閑上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['信意閑彈秋思時', '調清聲直韻疎遲', '近來漸喜無人聽', '琴格高低心自知'],
#   'title': array('彈秋思', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['春風先發苑中梅', '櫻杏桃梨次第開', '薺花榆莢深邨裏', '亦道春風爲我來'],
#   'title': array('春風', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洛陽陌上春長在', '惜別今來二十年', '唯覓少年心不得', '其餘萬事盡依然'],
#   'title': array('洛陽春', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['明月峽邊逢制使', '黃茅岸上是忠州', '到城莫說忠州惡', '無益虛教楊八愁'],
#   'title': array('送高侍御使迴因寄楊八', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['老去唯耽酒', '春來不著家', '去年來校晚', '不見洛陽花'],
#   'title': array('恨去年', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早起或因攜酒出', '晚歸多是看花迴', '若拋風景長閑坐', '自問東京作底來'],
#   'title': array('早出晚歸', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花寒嬾發鳥慵啼', '信馬閑行到日西', '何處未春先有思', '柳條無力魏王堤'],
#   'title': array('魏王堤', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['少年信美何曾久', '春日雖遲不再中', '歡笑勝愁歌勝哭', '請君莫道等頭空'],
#   'title': array('勸行樂', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['豈是交親向我疎', '老慵自愛閉門居', '近來漸喜知聞斷', '免惱嵇康索報書'],
#   'title': array('老慵', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['今夜調琴忽有情', '欲彈惆悵憶崔卿', '何人解愛中徽上', '秋思頭邊八九聲'],
#   'title': array('夜調琴憶崔少卿', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['子晉廟前山月明', '人聞往往夜吹笙', '鸞吟鳳唱聽無拍', '多似霓裳散序聲'],
#   'title': array('王子晉廟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['籃轝不乘乘晚涼', '相尋不遇亦無妨', '輕衣穩馬槐陰下', '自要閑行一兩坊'],
#   'title': array('晚出尋人不遇', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['潭邊霽後多清景', '橋下涼來足好風', '秋鶴一雙船一隻', '夜深相伴月明中'],
#   'title': array('舟中夜坐', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['多見朱門富貴人', '林園未畢即無身', '我今幸作西亭主', '已見池塘五度春'],
#   'title': array('題西亭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['碧油幢下捧新詩', '榮賤雖殊共一悲', '涕淚滿襟君莫怪', '甘泉侍從最多時'],
#   'title': array('奉酬李相公見示絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['繞池閑步看魚游', '正值兒童弄釣舟', '一種愛魚心各異', '我來施食爾垂鉤'],
#   'title': array('觀游魚', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小桃閑上小蓮船', '半採紅蓮半白蓮', '不似江南惡風浪', '芙蓉池在臥牀前'],
#   'title': array('看採蓮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['菱池如鏡淨無波', '白點花稀青角多', '時唱一聲新水調', '謾人道是採菱歌'],
#   'title': array('看採菱', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早世身如風裏燭', '暮年髮似鏡中絲', '誰人斷得人間事', '少夭堪傷老又悲'],
#   'title': array('夭老', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洗浪清風透水霜', '水邊閑坐一繩牀', '眼塵心垢見皆盡', '不是秋池是道場'],
#   'title': array('秋池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不思北省煙霄地', '不憶南宮風月天', '唯憶靜恭楊閣老', '小園新雪煖爐前'],
#   'title': array('新雪二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不思朱雀街東鼓', '不憶青龍寺後鐘', '唯憶夜深新雪後', '新昌臺上七株松'],
#   'title': array('新雪二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三鄉過日君年幾', '今日君年五十餘', '不獨年催身亦變', '校書郎變作尚書'],
#   'title': array('和微之任校書郎日過三鄉', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['別時十七今頭白', '惱亂君心三十年', '垂老休吟花月句', '恐君更結後身緣'],
#   'title': array('和微之十七與君別及隴月花枝之詠', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝榮殊可惜', '暮落實堪嗟', '若向花中比', '猶應勝眼花'],
#   'title': array('和微之歎槿花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三杯嵬峩忘機客', '百衲頭陀任運僧', '又有放慵巴郡守', '不營一事共騰騰'],
#   'title': array('戲贈蕭處士清禪師', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['莫驚寵辱虛憂喜', '莫計恩讐浪苦辛', '黃帝孔丘無處問', '安知不是夢中身'],
#   'title': array('疑夢二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['鹿疑鄭相終難辨', '蝶化莊生詎可知', '假使如今不是夢', '能長於夢幾多時'],
#   'title': array('疑夢二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['病眼少眠非守歲', '老心多感又臨春', '火銷燈盡天明後', '便是平頭六十人'],
#   'title': array('除夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['柳無氣力枝先動', '池有波紋冰盡開', '今日不知誰計會', '春風春水一時來'],
#   'title': array('府西池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自慚到府來周歲', '惠愛威稜一事無', '唯是改張官酒法', '漸從濁水作醍醐'],
#   'title': array('府酒五絕 變法', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['日午微風且暮寒', '春風冷峭雪乾殘', '碧氈帳下紅爐畔', '試爲來嘗一醆看'],
#   'title': array('府酒五絕 招客', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['甘露太甜非正味', '醴泉雖潔不芳馨', '桮中此物何人別', '柔旨之中有典刑'],
#   'title': array('府酒五絕 辨味', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['憶昔羈貧應舉年', '脫衣典酒曲江邊', '十千一斗猶賒飲', '何況官供不著錢'],
#   'title': array('府酒五絕 自勸', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['燭淚夜黏桃葉袖', '酒痕春汚石榴裙', '莫辭辛苦供歡宴', '老後思量悔煞君'],
#   'title': array('府酒五絕 諭妓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['如折芙蓉栽旱地', '似拋芍藥挂高枝', '雲埋水隔無人識', '唯有南賓太守知'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 一',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['同事空王歲月深', '相思遠寄定中吟', '遙知清淨中和化', '祗用金剛三昧心'],
#   'title': array('錢虢州以三堂絕句見寄因以本韻和之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['暮春風景初三日', '流世光陰半百年', '欲作閑遊無好伴', '半江惆悵却回船'],
#   'title': array('三月三日', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['四十九年身老日', '一百五夜月明天', '抱膝思量何事在', '癡男騃女喚鞦韆'],
#   'title': array('寒食夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['龍昌寺底開山路', '巴子臺前種柳林', '官職家鄉都忘却', '誰人會得使君心'],
#   'title': array('代州民問', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['宦情斗擻隨塵去', '鄉思銷磨逐日無', '唯擬騰騰作閑事', '遮渠不道使君愚'],
#   'title': array('荅州民', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['荔枝新熟雞冠色', '燒酒初開琥珀香', '欲摘一枝傾一醆', '西樓無客共誰嘗'],
#   'title': array('荔枝樓對酒', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['香毬趂拍回環匼', '花醆拋巡取次飛', '自入春來未同醉', '那能夜去獨先歸'],
#   'title': array('醉後贈人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三年留滯在江城', '草樹禽魚盡有情', '何處殷勤重回首', '東坡桃李種新成'],
#   'title': array('別種東坡花樹兩絕 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花林好住莫顦顇', '春至但知依舊春', '樓上明年新太守', '不妨還是愛花人'],
#   'title': array('別種東坡花樹兩絕 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['穿橋迸竹不依行', '恐礙行人被損傷', '我去自慙遺愛少', '不教君得似甘棠'],
#   'title': array('別橋上竹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅似燕支膩如粉', '傷心好物不須臾', '山中風起無時節', '明日重來得在無'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 二',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遙聞旅宿夢兄弟', '應爲郵亭名棣華', '名作棣華來早晚', '自題詩後屬楊家'],
#   'title': array('棣華驛見楊八題夢兄弟詩', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['萬里路長在', '六年身始歸', '所經多舊館', '大半主人非'],
#   'title': array('商山路有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['與君前後多遷謫', '五度經過此路隅', '笑問中庭老桐樹', '這回歸去免來無'],
#   'title': array('商山路驛桐樹昔與微之前後題名處', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['歲豐仍節儉', '時泰更銷兵', '聖念長如此', '何憂不太平'],
#   'title': array('太平樂詞二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['湛露浮堯酒', '薰風起舜歌', '願同堯舜意', '所樂在人和'],
#   'title': array('太平樂詞二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['霽色鮮宮殿', '秋聲脆管弦', '聖明千歲樂', '歲歲似今年'],
#   'title': array('小曲新詞二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅裾明月夜', '碧簟早秋時', '好向昭陽宿', '天涼玉漏遲'],
#   'title': array('小曲新詞二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝憎鶯百囀', '夜妒燕雙棲', '不慣經春別', '誰知到曉啼'],
#   'title': array('閨怨詞三首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['珠箔籠寒月', '紗窗背曉燈', '夜來巾上淚', '一半是春冰'],
#   'title': array('閨怨詞三首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['關山征戍遠', '閨閣別離難', '苦戰應顦顇', '寒衣不要寬'],
#   'title': array('閨怨詞三首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['已愁花落荒巖底', '復恨根生亂石間', '幾度欲移移不得', '天教拋擲在深山'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 三',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['禁苑殘鶯三四聲', '景遲風慢暮春情', '日西無事牆陰下', '閑蹋宮花獨自行'],
#   'title': array('殘春曲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['青門柳枝軟無力', '東風吹作黃金色', '街東酒薄醉易醒', '滿眼春愁銷不得'],
#   'title': array('長安春', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['行人南北分征路', '流水東西接御溝', '終日坡前恨離別', '謾名長樂是長愁'],
#   'title': array('長樂坡送人賦得愁', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['夜長無睡起階前', '寥落星河欲曙天', '十五年來明月夜', '何曾一夜不孤眠'],
#   'title': array('獨眠吟二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['獨眠客', '夜夜可憐長寂寂', '就中今夜最愁人', '涼月清風滿牀席'],
#   'title': array('獨眠吟二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅燭清樽久延佇', '出門入門天欲曙', '星稀月落竟不來', '煙柳朧朧鵲飛去'],
#   'title': array('期不至', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['春入長洲草又生', '鷓鴣飛起少人行', '年深不辨娃宮處', '夜夜蘇臺空月明'],
#   'title': array('長洲苑', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曾栽楊柳江南岸', '一別江南兩度春', '遙憶青青江岸上', '不知攀折是何人'],
#   'title': array('憶江柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南浦淒淒別', '西風嫋嫋秋', '一看腸一斷', '好去莫回頭'],
#   'title': array('南浦別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['悠悠一別已三年', '相望相思明月天', '腸斷青天望明月', '別來三十六回圓'],
#   'title': array('三年別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['冷碧新秋水', '殘紅半破蓮', '從來寥落意', '不似此池邊'],
#   'title': array('龍昌寺荷池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['深淺簷花千萬枝', '碧紗窗外囀黃鸝', '殘妝含淚下簾坐', '盡日傷春春不知'],
#   'title': array('傷春詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['淚濕羅巾夢不成', '夜深前殿按歌聲', '紅顏未老恩先斷', '斜倚薰籠坐到明'],
#   'title': array('後宮詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['吟詠霜毛句', '閑嘗雪水茶', '城中展眉處', '只是有元家'],
#   'title': array('吟元郎中白鬚詩兼飲雪水茶因題壁上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金馬東門隻日開', '漢庭待詔重仙才', '第三松樹非華表', '那得遼東鶴下來'],
#   'title': array('吳七郎中山人待制班中偶贈絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['再遊巫峽知何日', '總是秦人說向誰', '長憶小樓風月夜', '紅欄干上兩三枝'],
#   'title': array('寄題忠州小樓桃花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝客朝回回望好', '盡紆朱紫佩金銀', '此時獨與君爲伴', '馬上青袍唯兩人'],
#   'title': array('朝回和元少尹絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['鳳閣舍人京亞尹', '白頭俱未著緋衫', '南宫起請無消息', '朝散何時得入銜'],
#   'title': array('重和元少尹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['酒後高歌且放狂', '門前閑事莫思量', '猶嫌小戶長先醒', '不得多時住醉鄉'],
#   'title': array('醉後', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['絲綸閣下文書靜', '鐘鼓樓中刻漏長', '獨坐黃昏誰是伴', '紫薇花對紫微郎'],
#   'title': array('紫薇花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雨露由來一點恩', '爭能徧布及千門', '三千宮女胭脂面', '幾箇春來無淚痕'],
#   'title': array('後宮詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巴童巫女竹枝歌', '懊惱何人怨咽多', '暫聽遣君猶悵望', '長聞教我復如何'],
#   'title': array('聽竹枝贈李侍御', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['乍來天上宜清淨', '不用回頭望故山', '縱有舊遊君莫憶', '塵心起即墮人間'],
#   'title': array('馮閣老處見與嚴郎中酬和詩因戲贈絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['獨行獨語曲江頭', '回馬遲遲上樂遊', '蕭颯涼風與衰鬢', '誰教計會一時秋'],
#   'title': array('立秋日登樂遊園', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫袖紅弦明月中', '自彈自感闇低容', '弦凝指咽聲停處', '別有深情一萬重'],
#   'title': array('夜箏', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遠壁秋聲蟲絡絲', '入簷新影月低眉', '牀帷半故簾旌斷', '仍是初寒欲夜時'],
#   'title': array('舊房', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自問有何惆悵事', '寺門臨入却遲迴', '李家哭泣元家病', '柿葉紅時獨自來'],
#   'title': array('慈恩寺有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['霜菊花萎日', '風梧葉碎時', '怪來秋思苦', '緣詠秘書詩'],
#   'title': array('寄王祕書', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['黑花滿眼絲滿頭', '早衰因病病因愁', '宦途氣味已諳盡', '五十不休何日休'],
#   'title': array('自問', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['渠水暗流春凍解', '風吹日炙不成凝', '鳳池冷暖君諳在', '二月因何更有冰'],
#   'title': array('和韓侍郎題楊舍人林池見寄', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['半朽臨風樹', '多情立馬人', '開元一株柳', '長慶二年春'],
#   'title': array('勤政樓西老柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫微閤底送君回', '第二廳簾下不開', '莫戀漢南風景好', '峴山花盡早歸來'],
#   'title': array('送馮舍人閤老往襄陽', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['胡麻餅樣學京都', '麪脆油香新出爐', '寄與飢饞楊大使', '嘗看得似輔興無'],
#   'title': array('寄胡餅與楊萬州', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南陌傷心別', '東風滿把春', '莫欺楊柳弱', '勸酒勝於人'],
#   'title': array('莫走柳條詞送別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小園新種紅櫻樹', '閑遶花行便當遊', '何必更隨鞍馬隊', '衝泥蹋雨曲江頭'],
#   'title': array('酬韓侍郎張博士雨後遊曲江見寄', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曉來紅萼凋零盡', '但見空枝四五株', '前日狂風昨夜雨', '殘芳更合得存無'],
#   'title': array('惜小園花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['李君歿後共誰遊', '柳岸荷亭兩度秋', '獨繞曲江行一匝', '依前還立水邊愁'],
#   'title': array('曲江憶李十一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['青青一樹傷心色', '曾入幾人離恨中', '爲近都門多送別', '長條折盡減春風'],
#   'title': array('青門柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['白頭垂淚話梨園', '五十年前雨露恩', '莫問華清今日事', '滿山紅葉鏁宮門'],
#   'title': array('梨園弟子', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['一道殘陽鋪水中', '半江瑟瑟半江紅', '可憐九月初三夜', '露似真珠月似弓'],
#   'title': array('暮江吟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['春風搖蕩自東來', '折盡櫻桃綻盡梅', '惟餘思婦愁眉結', '無限春風吹不開'],
#   'title': array('思婦眉', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['奪寵心那慣', '尋思倚殿門', '不知移舊愛', '何處作新恩'],
#   'title': array('怨詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['寒月沈沈洞房靜', '真珠簾外梧桐影', '秋霜欲下手先知', '燈底裁縫剪刀冷'],
#   'title': array('空閨怨', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花房膩似紅蓮朵', '豔色鮮如紫牡丹', '唯有詩人能解愛', '丹青寫出與君看'],
#   'title': array('畫木蓮花圖寄元郎中', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲露青天月漏光', '中庭立久却歸房', '水窗席冷未能臥', '挑盡殘燈秋夜長'],
#   'title': array('秋房夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['菱葉縈波荷颭風', '荷花深處小船通', '逢郎欲語低頭笑', '碧玉搔頭落水中'],
#   'title': array('採蓮曲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['娉婷十五勝天仙', '白日姮娥旱地蓮', '何處閑教鸚鵡語', '碧紗窗下繡牀前'],
#   'title': array('鄰女', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['斜凭繡牀愁不動', '紅綃帶緩綠鬟低', '遼陽春盡無消息', '夜合花前日又西'],
#   'title': array('閨婦', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金錢買得牡丹栽', '何處辭叢別主來？紅芳堪惜還堪恨', '百處移將百處開'],
#   'title': array('移牡丹栽', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['江州去日聽箏夜', '白髮新生不願聞', '如今格是頭成雪', '彈到天明亦任君'],
#   'title': array('聽夜箏有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['弦清撥剌語錚錚', '背却殘燈就月明', '賴是心無惆悵事', '不然爭奈子弦聲'],
#   'title': array('琵琶', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['秋水蓮冠春草帬', '依稀風調似文君', '煩君玉指分明語', '知是琴心佯不聞'],
#   'title': array('和殷協律琴思', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['玉軫朱弦瑟瑟徽', '吳娃徵調奏湘妃', '分明曲裏愁雲雨', '似道蕭蕭郎不歸'],
#   'title': array('聽彈湘妃怨', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['燄短寒缸盡', '聲長曉漏遲', '年衰自無睡', '不是守三尸'],
#   'title': array('不睡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['好去民曹李判官', '少貪公事且謀歡', '男兒未死爭能料', '莫作忠州刺史看'],
#   'title': array('戲贈戶部李巡官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巫女廟花紅似粉', '昭君村柳翠於眉', '誠知老去風情少', '見此爭無一句詩'],
#   'title': array('題峽中石上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['蕃草席鋪楓葉岸', '竹枝歌送菊花杯', '明年尚作南賓守', '或可重陽更一來'],
#   'title': array('九日題塗溪', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['親故尋回駕', '妻孥未出關', '鳳皇池上月', '送我過商山'],
#   'title': array('宿陽城驛對月', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['往恨今愁應不殊', '題詩梁下又踟躕', '羨君猶夢見兄弟', '我到天明睡亦無'],
#   'title': array('赴杭州重宿棣華驛見楊八舊詩感題一絕', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['劫風火起燒荒宅', '苦海波生蕩破船', '力小無因救焚溺', '清涼山下且安禪'],
#   'title': array('寓言題僧', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['日下風高野路涼', '緩驅疲馬闇思鄉', '渭村秋物應如此', '棗赤梨紅稻穗黃'],
#   'title': array('內鄉村路作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['坐酌泠泠水', '看煎瑟瑟塵', '無由持一盌', '寄與愛茶人'],
#   'title': array('山泉煎茶有懷', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲雨三年別', '風波萬里行', '愁來正蕭索', '況見古人名'],
#   'title': array('吉祥寺見錢侍郎題名', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['虛白堂前衙退後', '更無一事到中心', '移牀就日簷間臥', '臥詠閑詩側枕琴'],
#   'title': array('虛白堂', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫粉筆含尖火燄', '紅胭脂染小蓮花', '芳情鄉思知多少', '惱得山僧悔出家'],
#   'title': array('題靈隱寺紅辛夷花戲酬光上人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['謝安山下空攜妓', '柳惲洲邊只賦詩', '爭及湖亭今日會', '嘲花詠水贈蛾眉'],
#   'title': array('候仙亭同諸客醉作', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['城上鼕鼕鼓', '朝衙復晚衙', '爲君慵不出', '落盡遶城花'],
#   'title': array('城上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['競渡相傳爲汨羅', '不能止遏意無他', '自經放逐來顦顇', '能校靈均死幾多'],
#   'title': array('和萬州楊使君四絕句 競渡', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['大見騰騰詩酒客', '不憂生計似君稀', '到舍將何作寒食', '滿船唯載樹陰歸'],
#   'title': array('送李校書趂寒食歸義興山居', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['闇誦黃庭經在口', '閑攜青竹杖隨身', '晚花新筍堪爲伴', '獨入林行不要人'],
#   'title': array('獨行', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫房日照胭脂拆', '素豔風吹膩粉開', '怪得獨饒脂粉態', '木蘭曾作女郎來'],
#   'title': array('戲題木蘭花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['重重照影看容鬢', '不見朱顏見白絲', '失却少年無處覓', '泥他湖水欲何爲'],
#   'title': array('湖中自照', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南館西軒兩樹櫻', '春條長足夏陰成', '素華朱實今雖盡', '碧葉風來別有情'],
#   'title': array('樟亭雙櫻樹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['郭外迎人月', '湖邊醒酒風', '誰留使君飲', '紅燭在舟中'],
#   'title': array('湖上夜飲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['晚涼思飲兩三杯', '召得江頭酒客來', '莫怕秋無伴醉物', '水蓮花盡木蓮開'],
#   'title': array('木芙蓉花下招客飲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['秋愛冷吟春愛醉', '詩家眷屬酒家仙', '若教早被浮名繫', '可得閑遊三十年'],
#   'title': array('重酬周判官', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['亂蓬爲鬢布爲巾', '曉蹋寒山自負薪', '一種錢唐江畔女', '著紅騎馬是何人'],
#   'title': array('代賣薪女贈諸妓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲水埋藏恩德洞', '簪裾束縛使君身', '暫來不宿歸州去', '應被山呼作俗人'],
#   'title': array('予以長慶二年冬十月到杭州明年秋九月始與范陽盧賈汝南周元範蘭陵蕭悅清河崔求東萊劉方輿同遊恩德寺之泉洞竹石籍甚久矣及茲目擊果愜心期因自嗟云到郡周歲方來入寺半日復去俯視朱綬仰睇白雲有媿於心遂留絕句',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['聞君澤畔傷春草', '憶在天門街裏時', '漠漠淒淒愁滿眼', '就中惆悵是江蘺'],
#   'title': array('和萬州楊使君四絕句 江邊草', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遙羨青雲裏', '祥鸞正引雛', '自憐滄海伴', '老蚌不生珠'],
#   'title': array('見李蘇州示男阿武詩自感成詠', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['頭陀獨宿寺西峰', '百尺禪菴半夜鐘', '煙月蒼蒼風瑟瑟', '更無雜樹對山松'],
#   'title': array('題清頭陀', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['形羸自覺朝飡減', '睡少偏知夜漏長', '實事漸消虛事在', '銀魚金帶遶腰光'],
#   'title': array('自歎二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['二毛曉落梳頭嬾', '兩眼春昏點藥頻', '唯有閑行猶得在', '心情未到不如人'],
#   'title': array('自歎二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小書樓下千竿竹', '深火爐前一醆燈', '此處與誰相伴宿', '燒丹道士坐禪僧'],
#   'title': array('竹樓宿', dtype=object)},
#  {'author': array('白居易', dtype=object),
# ...
#   'title': array('洛陽春', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['明月峽邊逢制使', '黃茅岸上是忠州', '到城莫說忠州惡', '無益虛教楊八愁'],
#   'title': array('送高侍御使迴因寄楊八', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['老去唯耽酒', '春來不著家', '去年來校晚', '不見洛陽花'],
#   'title': array('恨去年', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早起或因攜酒出', '晚歸多是看花迴', '若拋風景長閑坐', '自問東京作底來'],
#   'title': array('早出晚歸', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花寒嬾發鳥慵啼', '信馬閑行到日西', '何處未春先有思', '柳條無力魏王堤'],
#   'title': array('魏王堤', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['少年信美何曾久', '春日雖遲不再中', '歡笑勝愁歌勝哭', '請君莫道等頭空'],
#   'title': array('勸行樂', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['豈是交親向我疎', '老慵自愛閉門居', '近來漸喜知聞斷', '免惱嵇康索報書'],
#   'title': array('老慵', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['今夜調琴忽有情', '欲彈惆悵憶崔卿', '何人解愛中徽上', '秋思頭邊八九聲'],
#   'title': array('夜調琴憶崔少卿', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['子晉廟前山月明', '人聞往往夜吹笙', '鸞吟鳳唱聽無拍', '多似霓裳散序聲'],
#   'title': array('王子晉廟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['籃轝不乘乘晚涼', '相尋不遇亦無妨', '輕衣穩馬槐陰下', '自要閑行一兩坊'],
#   'title': array('晚出尋人不遇', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['潭邊霽後多清景', '橋下涼來足好風', '秋鶴一雙船一隻', '夜深相伴月明中'],
#   'title': array('舟中夜坐', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['多見朱門富貴人', '林園未畢即無身', '我今幸作西亭主', '已見池塘五度春'],
#   'title': array('題西亭', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['碧油幢下捧新詩', '榮賤雖殊共一悲', '涕淚滿襟君莫怪', '甘泉侍從最多時'],
#   'title': array('奉酬李相公見示絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['繞池閑步看魚游', '正值兒童弄釣舟', '一種愛魚心各異', '我來施食爾垂鉤'],
#   'title': array('觀游魚', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小桃閑上小蓮船', '半採紅蓮半白蓮', '不似江南惡風浪', '芙蓉池在臥牀前'],
#   'title': array('看採蓮', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['菱池如鏡淨無波', '白點花稀青角多', '時唱一聲新水調', '謾人道是採菱歌'],
#   'title': array('看採菱', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['早世身如風裏燭', '暮年髮似鏡中絲', '誰人斷得人間事', '少夭堪傷老又悲'],
#   'title': array('夭老', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['洗浪清風透水霜', '水邊閑坐一繩牀', '眼塵心垢見皆盡', '不是秋池是道場'],
#   'title': array('秋池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不思北省煙霄地', '不憶南宮風月天', '唯憶靜恭楊閣老', '小園新雪煖爐前'],
#   'title': array('新雪二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['不思朱雀街東鼓', '不憶青龍寺後鐘', '唯憶夜深新雪後', '新昌臺上七株松'],
#   'title': array('新雪二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三鄉過日君年幾', '今日君年五十餘', '不獨年催身亦變', '校書郎變作尚書'],
#   'title': array('和微之任校書郎日過三鄉', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['別時十七今頭白', '惱亂君心三十年', '垂老休吟花月句', '恐君更結後身緣'],
#   'title': array('和微之十七與君別及隴月花枝之詠', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝榮殊可惜', '暮落實堪嗟', '若向花中比', '猶應勝眼花'],
#   'title': array('和微之歎槿花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三杯嵬峩忘機客', '百衲頭陀任運僧', '又有放慵巴郡守', '不營一事共騰騰'],
#   'title': array('戲贈蕭處士清禪師', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['莫驚寵辱虛憂喜', '莫計恩讐浪苦辛', '黃帝孔丘無處問', '安知不是夢中身'],
#   'title': array('疑夢二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['鹿疑鄭相終難辨', '蝶化莊生詎可知', '假使如今不是夢', '能長於夢幾多時'],
#   'title': array('疑夢二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['病眼少眠非守歲', '老心多感又臨春', '火銷燈盡天明後', '便是平頭六十人'],
#   'title': array('除夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['柳無氣力枝先動', '池有波紋冰盡開', '今日不知誰計會', '春風春水一時來'],
#   'title': array('府西池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自慚到府來周歲', '惠愛威稜一事無', '唯是改張官酒法', '漸從濁水作醍醐'],
#   'title': array('府酒五絕 變法', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['日午微風且暮寒', '春風冷峭雪乾殘', '碧氈帳下紅爐畔', '試爲來嘗一醆看'],
#   'title': array('府酒五絕 招客', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['甘露太甜非正味', '醴泉雖潔不芳馨', '桮中此物何人別', '柔旨之中有典刑'],
#   'title': array('府酒五絕 辨味', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['憶昔羈貧應舉年', '脫衣典酒曲江邊', '十千一斗猶賒飲', '何況官供不著錢'],
#   'title': array('府酒五絕 自勸', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['燭淚夜黏桃葉袖', '酒痕春汚石榴裙', '莫辭辛苦供歡宴', '老後思量悔煞君'],
#   'title': array('府酒五絕 諭妓', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['如折芙蓉栽旱地', '似拋芍藥挂高枝', '雲埋水隔無人識', '唯有南賓太守知'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 一',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['同事空王歲月深', '相思遠寄定中吟', '遙知清淨中和化', '祗用金剛三昧心'],
#   'title': array('錢虢州以三堂絕句見寄因以本韻和之', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['暮春風景初三日', '流世光陰半百年', '欲作閑遊無好伴', '半江惆悵却回船'],
#   'title': array('三月三日', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['四十九年身老日', '一百五夜月明天', '抱膝思量何事在', '癡男騃女喚鞦韆'],
#   'title': array('寒食夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['龍昌寺底開山路', '巴子臺前種柳林', '官職家鄉都忘却', '誰人會得使君心'],
#   'title': array('代州民問', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['宦情斗擻隨塵去', '鄉思銷磨逐日無', '唯擬騰騰作閑事', '遮渠不道使君愚'],
#   'title': array('荅州民', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['荔枝新熟雞冠色', '燒酒初開琥珀香', '欲摘一枝傾一醆', '西樓無客共誰嘗'],
#   'title': array('荔枝樓對酒', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['香毬趂拍回環匼', '花醆拋巡取次飛', '自入春來未同醉', '那能夜去獨先歸'],
#   'title': array('醉後贈人', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['三年留滯在江城', '草樹禽魚盡有情', '何處殷勤重回首', '東坡桃李種新成'],
#   'title': array('別種東坡花樹兩絕 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花林好住莫顦顇', '春至但知依舊春', '樓上明年新太守', '不妨還是愛花人'],
#   'title': array('別種東坡花樹兩絕 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['穿橋迸竹不依行', '恐礙行人被損傷', '我去自慙遺愛少', '不教君得似甘棠'],
#   'title': array('別橋上竹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅似燕支膩如粉', '傷心好物不須臾', '山中風起無時節', '明日重來得在無'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 二',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遙聞旅宿夢兄弟', '應爲郵亭名棣華', '名作棣華來早晚', '自題詩後屬楊家'],
#   'title': array('棣華驛見楊八題夢兄弟詩', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['萬里路長在', '六年身始歸', '所經多舊館', '大半主人非'],
#   'title': array('商山路有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['與君前後多遷謫', '五度經過此路隅', '笑問中庭老桐樹', '這回歸去免來無'],
#   'title': array('商山路驛桐樹昔與微之前後題名處', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['歲豐仍節儉', '時泰更銷兵', '聖念長如此', '何憂不太平'],
#   'title': array('太平樂詞二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['湛露浮堯酒', '薰風起舜歌', '願同堯舜意', '所樂在人和'],
#   'title': array('太平樂詞二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['霽色鮮宮殿', '秋聲脆管弦', '聖明千歲樂', '歲歲似今年'],
#   'title': array('小曲新詞二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅裾明月夜', '碧簟早秋時', '好向昭陽宿', '天涼玉漏遲'],
#   'title': array('小曲新詞二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝憎鶯百囀', '夜妒燕雙棲', '不慣經春別', '誰知到曉啼'],
#   'title': array('閨怨詞三首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['珠箔籠寒月', '紗窗背曉燈', '夜來巾上淚', '一半是春冰'],
#   'title': array('閨怨詞三首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['關山征戍遠', '閨閣別離難', '苦戰應顦顇', '寒衣不要寬'],
#   'title': array('閨怨詞三首 三', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['已愁花落荒巖底', '復恨根生亂石間', '幾度欲移移不得', '天教拋擲在深山'],
#   'title': array('木蓮樹生巴峽山谷間巴民亦呼爲黃心樹大者高五丈涉冬不凋身如青楊有白文葉如桂厚大無脊花如蓮香色豔膩皆同獨房蘂有異四月初始開自開迨謝僅二十日忠州西北十里有鳴玉谿生者穠茂尤異元和十四年夏命道士母丘元志寫惜其遐僻因題三絕句云 三',
#         dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['禁苑殘鶯三四聲', '景遲風慢暮春情', '日西無事牆陰下', '閑蹋宮花獨自行'],
#   'title': array('殘春曲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['青門柳枝軟無力', '東風吹作黃金色', '街東酒薄醉易醒', '滿眼春愁銷不得'],
#   'title': array('長安春', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['行人南北分征路', '流水東西接御溝', '終日坡前恨離別', '謾名長樂是長愁'],
#   'title': array('長樂坡送人賦得愁', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['夜長無睡起階前', '寥落星河欲曙天', '十五年來明月夜', '何曾一夜不孤眠'],
#   'title': array('獨眠吟二首 一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['獨眠客', '夜夜可憐長寂寂', '就中今夜最愁人', '涼月清風滿牀席'],
#   'title': array('獨眠吟二首 二', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紅燭清樽久延佇', '出門入門天欲曙', '星稀月落竟不來', '煙柳朧朧鵲飛去'],
#   'title': array('期不至', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['春入長洲草又生', '鷓鴣飛起少人行', '年深不辨娃宮處', '夜夜蘇臺空月明'],
#   'title': array('長洲苑', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曾栽楊柳江南岸', '一別江南兩度春', '遙憶青青江岸上', '不知攀折是何人'],
#   'title': array('憶江柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南浦淒淒別', '西風嫋嫋秋', '一看腸一斷', '好去莫回頭'],
#   'title': array('南浦別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['悠悠一別已三年', '相望相思明月天', '腸斷青天望明月', '別來三十六回圓'],
#   'title': array('三年別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['冷碧新秋水', '殘紅半破蓮', '從來寥落意', '不似此池邊'],
#   'title': array('龍昌寺荷池', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['深淺簷花千萬枝', '碧紗窗外囀黃鸝', '殘妝含淚下簾坐', '盡日傷春春不知'],
#   'title': array('傷春詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['淚濕羅巾夢不成', '夜深前殿按歌聲', '紅顏未老恩先斷', '斜倚薰籠坐到明'],
#   'title': array('後宮詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['吟詠霜毛句', '閑嘗雪水茶', '城中展眉處', '只是有元家'],
#   'title': array('吟元郎中白鬚詩兼飲雪水茶因題壁上', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金馬東門隻日開', '漢庭待詔重仙才', '第三松樹非華表', '那得遼東鶴下來'],
#   'title': array('吳七郎中山人待制班中偶贈絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['再遊巫峽知何日', '總是秦人說向誰', '長憶小樓風月夜', '紅欄干上兩三枝'],
#   'title': array('寄題忠州小樓桃花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['朝客朝回回望好', '盡紆朱紫佩金銀', '此時獨與君爲伴', '馬上青袍唯兩人'],
#   'title': array('朝回和元少尹絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['鳳閣舍人京亞尹', '白頭俱未著緋衫', '南宫起請無消息', '朝散何時得入銜'],
#   'title': array('重和元少尹', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['酒後高歌且放狂', '門前閑事莫思量', '猶嫌小戶長先醒', '不得多時住醉鄉'],
#   'title': array('醉後', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['絲綸閣下文書靜', '鐘鼓樓中刻漏長', '獨坐黃昏誰是伴', '紫薇花對紫微郎'],
#   'title': array('紫薇花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雨露由來一點恩', '爭能徧布及千門', '三千宮女胭脂面', '幾箇春來無淚痕'],
#   'title': array('後宮詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['巴童巫女竹枝歌', '懊惱何人怨咽多', '暫聽遣君猶悵望', '長聞教我復如何'],
#   'title': array('聽竹枝贈李侍御', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['乍來天上宜清淨', '不用回頭望故山', '縱有舊遊君莫憶', '塵心起即墮人間'],
#   'title': array('馮閣老處見與嚴郎中酬和詩因戲贈絕句', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['獨行獨語曲江頭', '回馬遲遲上樂遊', '蕭颯涼風與衰鬢', '誰教計會一時秋'],
#   'title': array('立秋日登樂遊園', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫袖紅弦明月中', '自彈自感闇低容', '弦凝指咽聲停處', '別有深情一萬重'],
#   'title': array('夜箏', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['遠壁秋聲蟲絡絲', '入簷新影月低眉', '牀帷半故簾旌斷', '仍是初寒欲夜時'],
#   'title': array('舊房', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['自問有何惆悵事', '寺門臨入却遲迴', '李家哭泣元家病', '柿葉紅時獨自來'],
#   'title': array('慈恩寺有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['霜菊花萎日', '風梧葉碎時', '怪來秋思苦', '緣詠秘書詩'],
#   'title': array('寄王祕書', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['黑花滿眼絲滿頭', '早衰因病病因愁', '宦途氣味已諳盡', '五十不休何日休'],
#   'title': array('自問', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['渠水暗流春凍解', '風吹日炙不成凝', '鳳池冷暖君諳在', '二月因何更有冰'],
#   'title': array('和韓侍郎題楊舍人林池見寄', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['半朽臨風樹', '多情立馬人', '開元一株柳', '長慶二年春'],
#   'title': array('勤政樓西老柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['紫微閤底送君回', '第二廳簾下不開', '莫戀漢南風景好', '峴山花盡早歸來'],
#   'title': array('送馮舍人閤老往襄陽', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['胡麻餅樣學京都', '麪脆油香新出爐', '寄與飢饞楊大使', '嘗看得似輔興無'],
#   'title': array('寄胡餅與楊萬州', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['南陌傷心別', '東風滿把春', '莫欺楊柳弱', '勸酒勝於人'],
#   'title': array('莫走柳條詞送別', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['小園新種紅櫻樹', '閑遶花行便當遊', '何必更隨鞍馬隊', '衝泥蹋雨曲江頭'],
#   'title': array('酬韓侍郎張博士雨後遊曲江見寄', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['曉來紅萼凋零盡', '但見空枝四五株', '前日狂風昨夜雨', '殘芳更合得存無'],
#   'title': array('惜小園花', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['李君歿後共誰遊', '柳岸荷亭兩度秋', '獨繞曲江行一匝', '依前還立水邊愁'],
#   'title': array('曲江憶李十一', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['青青一樹傷心色', '曾入幾人離恨中', '爲近都門多送別', '長條折盡減春風'],
#   'title': array('青門柳', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['白頭垂淚話梨園', '五十年前雨露恩', '莫問華清今日事', '滿山紅葉鏁宮門'],
#   'title': array('梨園弟子', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['一道殘陽鋪水中', '半江瑟瑟半江紅', '可憐九月初三夜', '露似真珠月似弓'],
#   'title': array('暮江吟', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['春風搖蕩自東來', '折盡櫻桃綻盡梅', '惟餘思婦愁眉結', '無限春風吹不開'],
#   'title': array('思婦眉', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['奪寵心那慣', '尋思倚殿門', '不知移舊愛', '何處作新恩'],
#   'title': array('怨詞', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['寒月沈沈洞房靜', '真珠簾外梧桐影', '秋霜欲下手先知', '燈底裁縫剪刀冷'],
#   'title': array('空閨怨', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['花房膩似紅蓮朵', '豔色鮮如紫牡丹', '唯有詩人能解愛', '丹青寫出與君看'],
#   'title': array('畫木蓮花圖寄元郎中', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['雲露青天月漏光', '中庭立久却歸房', '水窗席冷未能臥', '挑盡殘燈秋夜長'],
#   'title': array('秋房夜', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['菱葉縈波荷颭風', '荷花深處小船通', '逢郎欲語低頭笑', '碧玉搔頭落水中'],
#   'title': array('採蓮曲', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['娉婷十五勝天仙', '白日姮娥旱地蓮', '何處閑教鸚鵡語', '碧紗窗下繡牀前'],
#   'title': array('鄰女', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['斜凭繡牀愁不動', '紅綃帶緩綠鬟低', '遼陽春盡無消息', '夜合花前日又西'],
#   'title': array('閨婦', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['金錢買得牡丹栽', '何處辭叢別主來？紅芳堪惜還堪恨', '百處移將百處開'],
#   'title': array('移牡丹栽', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['江州去日聽箏夜', '白髮新生不願聞', '如今格是頭成雪', '彈到天明亦任君'],
#   'title': array('聽夜箏有感', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['弦清撥剌語錚錚', '背却殘燈就月明', '賴是心無惆悵事', '不然爭奈子弦聲'],
#   'title': array('琵琶', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['秋水蓮冠春草帬', '依稀風調似文君', '煩君玉指分明語', '知是琴心佯不聞'],
#   'title': array('和殷協律琴思', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['玉軫朱弦瑟瑟徽', '吳娃徵調奏湘妃', '分明曲裏愁雲雨', '似道蕭蕭郎不歸'],
#   'title': array('聽彈湘妃怨', dtype=object)},
#  {'author': array('白居易', dtype=object),
#   'paragraphs': ['燄短寒缸盡', '聲長曉漏遲', '年衰自無睡', '不是守三尸'],
#   'title': array('不睡', dtype=object)}]
